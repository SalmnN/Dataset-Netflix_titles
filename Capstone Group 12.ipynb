# %%
import pandas as pd
df = pd.read_csv('cleaning_data_new.csv')
df
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
import pandas as pd
df1 = pd.read_csv('data_split_genre_imdb.csv')

# %%
print(pd.DataFrame(df1.columns))
# Out:
#                0
# 0        show_id
# 1           type
# 2          title
# 3       director
# 4           cast
# 5        country
# 6     date_added
# 7   release_year
# 8   rating_score
# 9       duration
# 10     listed_in
# 11   description
# 12   first_genre

# %%
import pandas as pd  #✔
df2 = pd.read_csv('data_2016_2020.csv')

# %%
import pandas as pd  #✔
df3 = pd.read_csv('data_2021.csv')

# %%
# Membaca tabel "data2016_2020" dan "data_split_genre_imdb" ke dalam DataFrame  #✔
data_2016_2020_df = pd.read_csv('data_2016_2020.csv')
data_split_genre_imdb_df = pd.read_csv('data_split_genre_imdb.csv')

# Melakukan penggabungan (merge) berdasarkan kolom 'type' atau kolom lain yang sesuai
merged_df = data_2016_2020_df.merge(data_split_genre_imdb_df, on='title', how='left')

# Mengisi kolom 'rating_imdb' di "data_2016_2020" dengan nilai dari "data_split_genre_imdb"
data_2016_2020_df['rating_imdb'] = merged_df['rating_score']  # Kolom 'rating_imdb' sesuai dengan nama kolom baru

# Menyimpan perubahan ke dalam tabel "data_2016_2020" jika diperlukan
data_2016_2020_df.to_csv('data_2016_2020_updated_left.csv', index=False)

# %%
import pandas as pd  #✔
df4 = pd.read_csv('data_2016_2020_updated_left.csv')
df4
# Out:
#     show_id     type                                       title  \
# 0     s1473    Movie                                Bobby Jasoos
# 1     s1492    Movie                                    AK vs AK
# 2     s1521  TV Show                             Paava Kadhaigal
# 3     s1543    Movie  Vir Das: Outside In - The Lockdown Special
# 4     s1562    Movie                                     Torbaaz
# ..      ...      ...                                         ...
# 788   s8773    Movie                       Yamla Pagla Deewana 2
# 789   s8774    Movie                         Yanda Kartavya Aahe
# 790   s8799    Movie                                    Zed Plus
# 791   s8800    Movie                                       Zenda
# 792   s8807    Movie                                      Zubaan
#
#                                               director  \
# 0                                         Samar Shaikh
# 1                                 Vikramaditya Motwane
# ...

# %%
import pandas as pd  #✔

jumlah_null = df6[df6['rating_imdb'].isnull()].shape[0]
print(jumlah_null)
# Out:
# 137

# %%
import pandas as pd  #✔

jumlah_not_null = df9['rating_imdb'].count()
print(jumlah_not_null)
# Out:
# 656

# %%
import pandas as pd  #✔
df5 = pd.read_csv('data_rating_2021.csv')

# %%
# Membaca tabel "data_2021" dan "data_rating_2021" ke dalam DataFrame  #✔
data_2021_df = pd.read_csv('data_2021.csv')
data_rating_2021_df = pd.read_csv('data_rating_2021.csv')

# Melakukan penggabungan (merge) berdasarkan kolom 'type' atau kolom lain yang sesuai
merged_df = data_2021_df.merge(data_rating_2021_df, on='title', how='left')

# Mengisi kolom 'rating_imdb' di "data_2021" dengan nilai dari "data_rating_2021"
data_2021_df['rating_imdb'] = merged_df['rating_score']  # Kolom 'rating_imdb' sesuai dengan nama kolom baru

# Menyimpan perubahan ke dalam tabel "data_2021" jika diperlukan
data_2021_df.to_csv('data_2021_updated_left.csv', index=False)

# %%
import pandas as pd  #✔
df6 = pd.read_csv('data_2021_updated_left.csv')
df6
# Out:
#    show_id   type                          title              director  \
# 0      s25  Movie                          Jeans            S. Shankar
# 1     s106  Movie               Angamaly Diaries  Lijo Jose Pellissery
# 2     s115  Movie                         Anjaam          Rahul Rawail
# 3     s117  Movie                         Dhanak       Nagesh Kukunoor
# 4     s119  Movie                        Gurgaon         Shanker Raman
# ..     ...    ...                            ...                   ...
# 76   s1411  Movie  Tribhanga - Tedhi Medhi Crazy        Renuka Shahane
# 77   s1423  Movie                       Apaharan           Prakash Jha
# 78   s1424  Movie                   BluffMaster!           Rohan Sippy
# 79   s1427  Movie                      Gangaajal           Prakash Jha
# 80   s1442  Movie                  Hello Brother           Sohail Khan
#
#                                                  cast country  date_added  \
# ...

# %%
import pandas as pd  #✔

jumlah_null = df10[df10['rating_imdb'].isnull()].shape[0]
print(jumlah_null)
# Out:
# 75

# %%
import pandas as pd  #✔

jumlah_not_null = df10['rating_imdb'].count()
print(jumlah_not_null)
# Out:
# 6

# %%
# Membaca tabel "data_2016_2020" dan "data_split_genre_imdb" ke dalam DataFrame   #✔
data_2021_updated_left_df = pd.read_csv('data_2021_updated_left.csv')
data_2016_2020_updated_left_df = pd.read_csv('data_2016_2020_updated_left.csv')

# Melakukan penggabungan (merge) berdasarkan kolom 'type' atau kolom lain yang sesuai
merged_df = data_2021_updated_left_df.merge(data_2016_2020_updated_left_df,
                                            on= ["show_id", "type", "title", "director", "cast", "country", "date_added", "release_year", "rating", "duration", "listed_in", "description", "first_genre", "rating_imdb"],
                                            how='outer')

# Mengisi kolom 'rating_imdb' di "data_2016_2020" dengan nilai dari "data_split_genre_imdb"
#data_2021_df['rating_imdb'] = merged_df['rating_score']  # Kolom 'rating_imdb' sesuai dengan nama kolom baru

# Menyimpan hasil penggabungan ke dalam file CSV
merged_df.to_csv('data_merged.csv', index=False)

# %%
import pandas as pd   #✔
df7 = pd.read_csv('data_merged.csv')
df7
# Out:
#     show_id   type                  title                 director  \
# 0       s25  Movie                  Jeans               S. Shankar
# 1      s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 2      s115  Movie                 Anjaam             Rahul Rawail
# 3      s117  Movie                 Dhanak          Nagesh Kukunoor
# 4      s119  Movie                Gurgaon            Shanker Raman
# ..      ...    ...                    ...                      ...
# 869   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 870   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 871   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 872   s8800  Movie                  Zenda           Avadhoot Gupte
# 873   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                   cast country  date_added  \
# 0    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India  2021-09-21
# ...

# %%
import pandas as pd   #✔

jumlah_null = df11[df11['rating_imdb'].isnull()].shape[0]
print(jumlah_null)
# Out:
# 212

# %%
import pandas as pd   #✔

# Membaca tabel "data_merged" ke dalam DataFrame
data = pd.read_csv('data_merged.csv')

# Bagian 1: Data dengan nilai null dalam kolom "rating_imdb"
data_null = data[data['rating_imdb'].isnull()]

# Bagian 2: Data tanpa nilai null dalam kolom "rating_imdb"
data_not_null = data[data['rating_imdb'].notnull()]

# Tampilkan atau proses kedua bagian data sesuai kebutuhan Anda
data_null.to_csv('data_null.csv', index=False)
#print(data_null)

data_not_null.to_csv('data_not_null.csv', index=False)
#print(data_not_null)

# %%
import pandas as pd  #✔
df8 = pd.read_csv('data_null.csv')
df8
# Out:
#     show_id   type                  title              director  \
# 0       s25  Movie                  Jeans            S. Shankar
# 1      s106  Movie       Angamaly Diaries  Lijo Jose Pellissery
# 2      s115  Movie                 Anjaam          Rahul Rawail
# 3      s117  Movie                 Dhanak       Nagesh Kukunoor
# 4      s119  Movie                Gurgaon         Shanker Raman
# ..      ...    ...                    ...                   ...
# 207   s3533  Movie  Ee Nagaraniki Emaindi       Tharun Bhascker
# 208   s3976  Movie                    Sei              Raj Babu
# 209   s7164  Movie         Kacche Dhaagey            Buta Singh
# 210   s7689  Movie            P Se PM Tak           Kundan Shah
# 211   s8137  Movie                  Swami       Basu Chatterjee
#
#                                                   cast country  date_added  \
# 0    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India  2021-09-21
# ...

# %% [markdown]
# Setelah ini aku input data yang null dengan avg rating per genre di google spreadsheet

# %%
import pandas as pd  #✔

data_not_null = pd.read_csv('data_not_null.csv')
data_not_null
# Out:
#     show_id   type                  title  \
# 0      s872  Movie     Sardar Ka Grandson
# 1      s910  Movie              Milestone
# 2      s960  Movie           The Disciple
# 3     s1024  Movie        Ajeeb Daastaans
# 4     s1166  Movie               Pagglait
# ..      ...    ...                    ...
# 657   s8773  Movie  Yamla Pagla Deewana 2
# 658   s8774  Movie    Yanda Kartavya Aahe
# 659   s8799  Movie               Zed Plus
# 660   s8800  Movie                  Zenda
# 661   s8807  Movie                 Zubaan
#
#                                               director  \
# 0                                        Kaashvie Nair
# 1                                             Ivan Ayr
# 2                                    Chaitanya Tamhane
# 3    Shashank Khaitan, Raj Mehta, Neeraj Ghaywan, K...
# 4                                           Umesh Bist
# ..                                                 ...
# 657                                     Sangeeth Sivan
# ...

# %%
import pandas as pd  #✔

jumlah_not_null = data_not_null['rating_imdb'].count()
print(jumlah_not_null)
# Out:
# 662

# %%
import pandas as pd  #✔

# Baca kedua file CSV ke dalam DataFrames
data_not_null = pd.read_csv('data_not_null.csv')
data_null_filled = pd.read_csv('data_null_filled.csv')

#data_null_filled.csv adalah file data_null yang sudah di isi dengan avg rating per genre

# Gabungkan DataFrames menggunakan metode concat
combined_data = pd.concat([data_not_null, data_null_filled], ignore_index=True)

# Simpan hasil penggabungan ke dalam satu file CSV
#combined_data.to_csv('combined_data.csv', index=False)

combined_data
# Out:
#     show_id   type                  title  \
# 0      s872  Movie     Sardar Ka Grandson
# 1      s910  Movie              Milestone
# 2      s960  Movie           The Disciple
# 3     s1024  Movie        Ajeeb Daastaans
# 4     s1166  Movie               Pagglait
# ..      ...    ...                    ...
# 869   s3533  Movie  Ee Nagaraniki Emaindi
# 870   s3976  Movie                    Sei
# 871   s7164  Movie         Kacche Dhaagey
# 872   s7689  Movie            P Se PM Tak
# 873   s8137  Movie                  Swami
#
#                                               director  \
# 0                                        Kaashvie Nair
# 1                                             Ivan Ayr
# 2                                    Chaitanya Tamhane
# 3    Shashank Khaitan, Raj Mehta, Neeraj Ghaywan, K...
# 4                                           Umesh Bist
# ..                                                 ...
# 869                                    Tharun Bhascker
# ...

# %%
import pandas as pd  #✔

jumlah_null = combined_data[combined_data['rating_imdb'].isnull()].shape[0]
print(jumlah_null)
# Out:
# 0

# %%
import pandas as pd   #✔

# Baca kedua file CSV ke dalam DataFrames
data_not_null = pd.read_csv('data_not_null.csv')
data_null_filled = pd.read_csv('data_null_filled.csv')

# Gabungkan DataFrames menggunakan metode concat
combined_data = pd.concat([data_not_null, data_null_filled], ignore_index=True)

# Simpan hasil penggabungan ke dalam satu file CSV
combined_data.to_csv('combined_data.csv', index=False)
